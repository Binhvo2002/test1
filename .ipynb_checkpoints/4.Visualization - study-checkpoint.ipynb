# %%
import seaborn as sns 
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

tips = sns.load_dataset('tips')
display(tips)

air = sns.load_dataset('flights')
air
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]
#      year month  passengers
# 0    1949   Jan         112
# 1    1949   Feb         118
# 2    1949   Mar         132
# 3    1949   Apr         129
# 4    1949   May         121
# ..    ...   ...         ...
# 139  1960   Aug         606
# 140  1960   Sep         508
# 141  1960   Oct         461
# 142  1960   Nov         390
# 143  1960   Dec         432
#
# [144 rows x 3 columns]

# %%
sns.lmplot(x='total_bill', y = 'tip', data = tips)

# %%
# Matplotlib
# Vẽ biều đồ điểm trục X là số total_bill, Y là tip
plt.scatter(tips['total_bill'], tips['tip']);

# %%
sns.scatterplot(data = tips, x = "total_bill", y='tip');
sns.set()

# %%
air2 = air.groupby('year')['passengers'].mean()
display(air2)
plt.plot(air2.index, air2)
# Out:
# year
# 1949    126.666667
# 1950    139.666667
# 1951    170.166667
# 1952    197.000000
# 1953    225.000000
# 1954    238.916667
# 1955    284.000000
# 1956    328.250000
# 1957    368.416667
# 1958    381.000000
# 1959    428.333333
# 1960    476.166667
# Name: passengers, dtype: float64

# %%
sns.lineplot(data = air, x = 'year', y = "passengers", estimator = 'mean')
# Out:
# <AxesSubplot: xlabel='year', ylabel='passengers'>

# %%
# Seaborn
# sns.lineplot(data = df, x = 'tên cột 1', y = 'tên cột 2', estimator = 'phép toán')
sns.lineplot(data = air, x='year', y='passengers', estimator='mean');
# Matplotlib
# Vẽ biểu đồ đường số lượng khách trung bình hàng tháng theo từng năm
air2 = air.groupby('year')['passengers'].mean()
display(air2)
plt.plot(air2.index, air2);
# Out:
# year
# 1949    126.666667
# 1950    139.666667
# 1951    170.166667
# 1952    197.000000
# 1953    225.000000
# 1954    238.916667
# 1955    284.000000
# 1956    328.250000
# 1957    368.416667
# 1958    381.000000
# 1959    428.333333
# 1960    476.166667
# Name: passengers, dtype: float64

# %%
sns.lmplot(x = 'total_bill', y='tip', hue ='smoker', data = tips)

# %%
plt.scatter(x='total_bill', y='tip', data =tips)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Input In [38], in <cell line: 2>()
#       1 plt.scatter(x='total_bill', y='tip', data =tips)
# ----> 2 fig, ax = plt.subplot(0,0)
#       3 ax = plt.gca()
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\matplotlib\pyplot.py:1252, in subplot(*args, **kwargs)
#    1249 fig = gcf()
#    1251 # First, search for an existing subplot with a matching spec.
# -> 1252 key = SubplotSpec._from_subplot_args(fig, args)
#    1254 for ax in fig.axes:
#    1255     # if we found an Axes at the position sort out if we can re-use it
#    1256     if hasattr(ax, 'get_subplotspec') and ax.get_subplotspec() == key:
#    1257         # if the user passed no kwargs, re-use
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\matplotlib\gridspec.py:598, in SubplotSpec._from_subplot_args(figure, args)
#     596     rows, cols, num = args
#     597 else:
# --> 598     raise TypeError(f"subplot() takes 1 or 3 positional arguments but "
#     599                     f"{len(args)} were given")
#     601 gs = GridSpec._check_gridspec_exists(figure, rows, cols)
#     602 if gs is None:
#
# TypeError: subplot() takes 1 or 3 positional arguments but 2 were given

# %%
smoker = tips[tips['smoker'] == "Yes"]
no_smoker = tips[tips['smoker'] == "No"]
# ax = plt.gca()
plt.atter(smoker)
plt.scatter(no_smoker)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [45], in <cell line: 4>()
#       2 no_smoker = tips[tips['smoker'] == "No"]
#       3 # ax = plt.gca()
# ----> 4 pltcatter(smoker)
#       5 plt.scatter(no_smoker)
#
# NameError: name 'pltcatter' is not defined
