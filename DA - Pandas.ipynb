# %%
import pandas as pd
import numpy as np

# %%
df = pd.DataFrame()
print(df)
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %%
lst = ['Kế toán','Kinh doanh','Tiếp thị']
df = pd.DataFrame(lst)
df
# Out:
#             0
# 0     Kế toán
# 1  Kinh doanh
# 2    Tiếp thị

# %%
tuples = [('Kế toán',2000),('Kinh doanh',2100),('Tiếp thị',1900)]
df = pd.DataFrame(tuples)
df
# Out:
#             0     1
# 0     Kế toán  2000
# 1  Kinh doanh  2100
# 2    Tiếp thị  1900

# %%
dic = {'Nghề':['Kế toán','Kinh doanh','Tiếp thị'],
      'Lương':[2000,2100,1900]}
df = pd.DataFrame(dic)
df
# Out:
#          Nghề  Lương
# 0     Kế toán   2000
# 1  Kinh doanh   2100
# 2    Tiếp thị   1900

# %%
arr = np.array([51,65,48,59,68])
seri2 = pd.Series(arr)
seri2
# Out:
# 0    51
# 1    65
# 2    48
# 3    59
# 4    68
# dtype: int32

# %%
import pandas as pd
import numpy as np
data = pd.read_csv('FoodPrice_in_Turkey.csv',
                  header = 0, encoding = 'ISO-8859-1')
data = pd.read_csv('FoodPrice_in_Turkey.csv',
                  header = 0, encoding = 'ISO-8859-1')
print('*'*20,'Nhập dữ liệu thành công','*'*20)
display(data)
data.columns
# Out:
# ******************** Nhập dữ liệu thành công ********************
#                  Place  ProductId              ProductName  UmId UmName  \
# 0     National Average         52            Rice - Retail     5     KG
# 1     National Average         52            Rice - Retail     5     KG
# 2     National Average         52            Rice - Retail     5     KG
# 3     National Average         52            Rice - Retail     5     KG
# 4     National Average         52            Rice - Retail     5     KG
# ...                ...        ...                      ...   ...    ...
# 7376             Izmir        502  Cocoa (powder) - Retail     5     KG
# 7377             Izmir        502  Cocoa (powder) - Retail     5     KG
# 7378             Izmir        502  Cocoa (powder) - Retail     5     KG
# 7379             Izmir        502  Cocoa (powder) - Retail     5     KG
# 7380             Izmir        502  Cocoa (powder) - Retail     5     KG
#
#       Month  Year    Price
# 0         5  2013   4.4920
# 1         6  2013   4.5786
# 2        11  2013   4.7865
# 3        12  2013   5.1337
# 4         1  2014   5.5099
# ...     ...   ...      ...
# 7376      8  2019  47.9040
# 7377      9  2019  49.1176
# 7378     10  2019  50.8347
# 7379     11  2019  51.7985
# 7380     12  2019  51.6071
#
# [7381 rows x 8 columns]
# Index(['Place', 'ProductId', 'ProductName', 'UmId', 'UmName', 'Month', 'Year',
#        'Price'],
#       dtype='object')

# %%
data.columns
# Out:
# Index(['Place', 'ProductId', 'ProductName', 'UmId', 'UmName', 'Month', 'Year',
#        'Price'],
#       dtype='object')

# %%
data.columns = ['Địa điểm','Mã SP','Tên SP','Đơn vị','Tên đơn vị','Tháng','Năm','Giá']
display(data)
# Out:
#               Địa điểm  Mã SP                   Tên SP  Đơn vị Tên đơn vị  \
# 0     National Average     52            Rice - Retail       5         KG
# 1     National Average     52            Rice - Retail       5         KG
# 2     National Average     52            Rice - Retail       5         KG
# 3     National Average     52            Rice - Retail       5         KG
# 4     National Average     52            Rice - Retail       5         KG
# ...                ...    ...                      ...     ...        ...
# 7376             Izmir    502  Cocoa (powder) - Retail       5         KG
# 7377             Izmir    502  Cocoa (powder) - Retail       5         KG
# 7378             Izmir    502  Cocoa (powder) - Retail       5         KG
# 7379             Izmir    502  Cocoa (powder) - Retail       5         KG
# 7380             Izmir    502  Cocoa (powder) - Retail       5         KG
#
#       Tháng   Năm      Giá
# 0         5  2013   4.4920
# 1         6  2013   4.5786
# 2        11  2013   4.7865
# 3        12  2013   5.1337
# 4         1  2014   5.5099
# ...     ...   ...      ...
# 7376      8  2019  47.9040
# 7377      9  2019  49.1176
# 7378     10  2019  50.8347
# 7379     11  2019  51.7985
# 7380     12  2019  51.6071
#
# [7381 rows x 8 columns]

# %%
# Việt hóa tên các cột
# Đổi tên chỉ 1 cột xác định
# data.rename(columns = {'Place':'Địa điểm'}, inplace=True)

# Đổi tên chỉ 1 vài cột xác định
# data.rename(columns = {'ProductId':'Mã sản phẩm', 'ProductName':'Tên sản phẩm'}, inplace=True)
# data.rename(columns = {'UmId':'Số lượng', 'UmName':'Tên đơn vị'}, inplace=False) #Bảng data không thay đổi

# Đổi tên toàn bộ các cột (Yêu cầu liệt kê đầy đủ tên cột mới và theo đúng thứ tự)
data.columns = ['Địa điểm', 'Mã SP', 'Tên SP', 'Đơn vị', 'Tên đơn vị', 'Tháng', 'Năm', 'Giá'] #Phải đủ số lượng tên các cột

data
# Out:
#   Input In [3]
#     data.global
#          ^
# SyntaxError: invalid syntax

# %%
import pandas as pd
import numpy as np
data = pd.read_csv('FoodPrice_in_Turkey.csv',
                  header = 0, encoding = 'ISO-8859-1')
print('*'*20,'Nhập dữ liệu thành công','*'*20)

data.loc[data.shape[0]]=['Sài Gòn',3000,'Dưa hấu',5,'KG',10,6,2022,50.000,0,np.NaN]
display(data)
# Out:
# ******************** Nhập dữ liệu thành công ********************
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Input In [6], in <cell line: 7>()
#       3 data = pd.read_csv('FoodPrice_in_Turkey.csv',
#       4                   header = 0, encoding = 'ISO-8859-1')
#       5 print('*'*20,'Nhập dữ liệu thành công','*'*20)
# ----> 7 data.loc[data.shape[0]]=['Sài Gòn',3000,'Dưa hấu',5,'KG',10,6,2022,50.000,0,np.NaN]
#       8 display(data)
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\core\indexing.py:819, in _LocationIndexer.__setitem__(self, key, value)
#     816 self._has_valid_setitem_indexer(key)
#     818 iloc = self if self.name == "iloc" else self.obj.iloc
# --> 819 iloc._setitem_with_indexer(indexer, value, self.name)
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\core\indexing.py:1786, in _iLocIndexer._setitem_with_indexer(self, indexer, value, name)
#    1783     indexer, missing = convert_missing_indexer(indexer)
#    1785     if missing:
# -> 1786         self._setitem_with_indexer_missing(indexer, value)
#    1787         return
#    1789 if name == "loc":
#    1790     # must come after setting of missing
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\core\indexing.py:2156, in _iLocIndexer._setitem_with_indexer_missing(self, indexer, value)
#    2153     if is_list_like_indexer(value):
#    2154         # must have conforming columns
#    2155         if len(value) != len(self.obj.columns):
# -> 2156             raise ValueError("cannot set a row with mismatched columns")
#    2158     value = Series(value, index=self.obj.columns, name=indexer)
#    2160 if not len(self.obj):
#    2161     # We will ignore the existing dtypes instead of using
#    2162     #  internals.concat logic
#
# ValueError: cannot set a row with mismatched columns

# %%
data.loc[-1] = data.loc[0]
data.loc[0] = ['Đà Nẵng', 3002, 'Mỳ Quảng', 5, 'Tô', 10, 2022, 20, 100.000, 10, 'NaN']
data = data.sort_index()
data.index = data.index + 1

data.loc[0.5]= ['Đà Nắng',3002,'Mì quảng',5,'tô',10,9,2022,100.000,20,np.NaN]

data = data.sort_index().reset_index(drop=True)

# %%
truy cập 1 dòng: 
    df.loc[ : ] => truy vấn nhiều dòng
# Out:
#   Input In [3]
#     truy cập 1 dòng:
#          ^
# SyntaxError: invalid syntax

# %%
import pandas as pd
data = pd.read_csv('FoodPrice_in_Turkey.csv',
                  header = 0, encoding = 'ISO-8859-1')
print('*'*20,'Nhập dữ liệu thành công','*'*20)
data.loc[-1] = ['ThanhHoa', 66, 'Nem chua', 5, 'KG', 6, 2022, 66.1234]
data.loc[2.5] = ['DaNang', 77, 'BTCTH', 5, 'KG', 6, 2022, 77.1234]
data = data.sort_index()
display(data.head(10))

data.iloc[[4,0]]

#data.iloc[0:5]
data.loc[-1:2.5]
# Out:
# ******************** Nhập dữ liệu thành công ********************
#                  Place  ProductId    ProductName  UmId UmName  Month  Year  \
# -1.0          ThanhHoa         66       Nem chua     5     KG      6  2022
#  0.0  National Average         52  Rice - Retail     5     KG      5  2013
#  1.0  National Average         52  Rice - Retail     5     KG      6  2013
#  2.0  National Average         52  Rice - Retail     5     KG     11  2013
#  2.5            DaNang         77          BTCTH     5     KG      6  2022
#  3.0  National Average         52  Rice - Retail     5     KG     12  2013
#  4.0  National Average         52  Rice - Retail     5     KG      1  2014
#  5.0  National Average         52  Rice - Retail     5     KG      2  2014
#  6.0  National Average         52  Rice - Retail     5     KG      3  2014
#  7.0  National Average         52  Rice - Retail     5     KG      5  2014
#
#         Price
# -1.0  66.1234
#  0.0   4.4920
#  1.0   4.5786
#  2.0   4.7865
#  2.5  77.1234
#  3.0   5.1337
#  4.0   5.5099
#  5.0   5.8146
#  6.0   6.0014
#  7.0   6.3202
#                  Place  ProductId    ProductName  UmId UmName  Month  Year  \
# -1.0          ThanhHoa         66       Nem chua     5     KG      6  2022
#  0.0  National Average         52  Rice - Retail     5     KG      5  2013
#  1.0  National Average         52  Rice - Retail     5     KG      6  2013
#  2.0  National Average         52  Rice - Retail     5     KG     11  2013
#  2.5            DaNang         77          BTCTH     5     KG      6  2022
#
#         Price
# -1.0  66.1234
#  0.0   4.4920
#  1.0   4.5786
#  2.0   4.7865
#  2.5  77.1234

# %%
import pandas as pd
data = pd.read_csv('shopeep_koreantop_clothing_shop_data.csv',header = 0, encoding = 'ISO-8859-1')
# data.groupby('name')[['rating_bad','rating_good','rating_normal']].sum()
# data.pivot_table(values='Price',index='ProductName',columns='Year',aggfunc ='max')

# %%
import pandas as pd
data = pd.read_csv('shopeep_koreantop_clothing_shop_data.csv',header = 0, encoding = 'ISO-8859-1')
data.head()
temp = pd.to_datetime(data.loc[:,'response_time'],format =' %H:%M:%S')
temp.head()
# Out:
# 0   1900-01-01 10:13:55
# 1   1900-01-01 10:43:05
# 2   1900-01-01 08:32:07
# 3   1900-01-01 09:10:38
# 4   1900-01-01 11:40:59
# Name: response_time, dtype: datetime64[ns]
